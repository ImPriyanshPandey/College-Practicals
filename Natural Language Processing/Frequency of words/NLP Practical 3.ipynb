# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter
import string

# Download required data
nltk.download('punkt')
nltk.download('stopwords')

# Sample text
text = """
Natural Language Processing, or NLP, is a fascinating branch of artificial intelligence that focuses on the interaction between computers and human language.
The ultimate goal of NLP is to read, decipher, understand, and make sense of human languages in a manner that is valuable. Most NLP techniques rely on machine learning to derive meaning from human languages.
In fact, a typical machine learning system uses a combination of algorithms, carefully designed to perform tasks like sentiment analysis, machine translation, and text summarization. 
Data is the foundation of any NLP model. By feeding large amounts of text data into a computer, we teach it to recognize patterns. 
Over time, the computer becomes better at predicting the next word in a sentence or understanding the context of a paragraph.
As technology advances, NLP will continue to shape how we interact with machines, making our daily lives easier and far more connected today.
"""

# Convert to lowercase
text = text.lower()

# Tokenize text
tokens = word_tokenize(text)

# Remove punctuation
tokens = [word for word in tokens if word not in string.punctuation]

# Remove stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in tokens if word not in stop_words]

# Count word frequency
word_freq = Counter(filtered_words)

# Display most common words
print("Most Common Words:")
for word, freq in word_freq.most_common():
    print(word, ":", freq)
# Out:
# Most Common Words:
# nlp : 5
# human : 3
# machine : 3
# language : 2
# languages : 2
# learning : 2
# text : 2
# data : 2
# computer : 2
# natural : 1
# processing : 1
# fascinating : 1
# branch : 1
# artificial : 1
# intelligence : 1
# focuses : 1
# interaction : 1
# computers : 1
# ultimate : 1
# goal : 1
# read : 1
# decipher : 1
# understand : 1
# make : 1
# sense : 1
# manner : 1
# valuable : 1
# techniques : 1
# rely : 1
# derive : 1
# meaning : 1
# fact : 1
# typical : 1
# system : 1
# uses : 1
# combination : 1
# algorithms : 1
# carefully : 1
# designed : 1
# perform : 1
# tasks : 1
# like : 1
# sentiment : 1
# analysis : 1
# translation : 1
# summarization : 1
# foundation : 1
# model : 1
# feeding : 1
# large : 1
# amounts : 1
# teach : 1
# recognize : 1
# patterns : 1
# time : 1
# becomes : 1
# better : 1
# predicting : 1
# next : 1
# word : 1
# sentence : 1
# understanding : 1
# context : 1
# paragraph : 1
# technology : 1
# advances : 1
# continue : 1
# shape : 1
# ...
