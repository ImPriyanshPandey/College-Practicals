# %%
import nltk
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')

text = "Python is the most easiest and readable programming language. Unlike other programming languages, it reads code line by line and stops where it finds an error."

print("Original Text:")
print(text)


text = text.lower()

tokens = word_tokenize(text)
print("\nTokens:")
print(tokens)

tokens = [word for word in tokens if word not in string.punctuation]
print("\nAfter Removing Punctuation:")
print(tokens)

stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word not in stop_words]
print("\nAfter Removing Stopwords:")
print(filtered_tokens)

stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_tokens]
print("\nStemmed Words:")
print(stemmed_words)


lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print("\nLemmatized Words:")
print(lemmatized_words)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Vicky\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Vicky\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Vicky\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Vicky\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# Original Text:
# Python is the most easiest and readable programming language. Unlike other programming languages, it reads code line by line and stops where it finds an error.
#
# Tokens:
# ['python', 'is', 'the', 'most', 'easiest', 'and', 'readable', 'programming', 'language', '.', 'unlike', 'other', 'programming', 'languages', ',', 'it', 'reads', 'code', 'line', 'by', 'line', 'and', 'stops', 'where', 'it', 'finds', 'an', 'error', '.']
#
# After Removing Punctuation:
# ['python', 'is', 'the', 'most', 'easiest', 'and', 'readable', 'programming', 'language', 'unlike', 'other', 'programming', 'languages', 'it', 'reads', 'code', 'line', 'by', 'line', 'and', 'stops', 'where', 'it', 'finds', 'an', 'error']
#
# After Removing Stopwords:
# ['python', 'easiest', 'readable', 'programming', 'language', 'unlike', 'programming', 'languages', 'reads', 'code', 'line', 'line', 'stops', 'finds', 'error']
#
# Stemmed Words:
# ['python', 'easiest', 'readabl', 'program', 'languag', 'unlik', 'program', 'languag', 'read', 'code', 'line', 'line', 'stop', 'find', 'error']
#
# Lemmatized Words:
# ['python', 'easiest', 'readable', 'programming', 'language', 'unlike', 'programming', 'language', 'read', 'code', 'line', 'line', 'stop', 'find', 'error']
